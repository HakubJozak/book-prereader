# %%
import sklearn, numpy, scipy
import pandas as pd
df = pd.read_csv("data/word_freq100k.csv", header=None)

# %%
import matplotlib.pyplot as plt
plt.plot((df[3]))
plt.show()

# %%
df[4] = df[2].str.len()
df.head()
df = df[df[4] > 3]
df = df[df[4] < 15]
df.columns = ['ii', 'id', 'word', 'freq', 'len']
df.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ii</th>
#       <th>id</th>
#       <th>word</th>
#       <th>freq</th>
#       <th>len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>52313</td>
#       <td>21</td>
#       <td>mcintyre</td>
#       <td>2.0</td>
#       <td>8.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>52314</td>
#       <td>60</td>
#       <td>bit/s</td>
#       <td>2.0</td>
#       <td>5.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>52316</td>
#       <td>182</td>
#       <td>hedwig</td>
#       <td>2.0</td>
#       <td>6.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
# ...

# %%
plt.scatter(df['freq'],df['len'])
plt.show()

# %%
tfid = pd.read_csv("data/calc_td.csv", header=None)
tfid.head()
word_index = tfid[1].values
# print(word_index)
# tfscore = tfid[2].values
# bla = df[4]
# print(tfscore)

# %%
tfid.columns = ['i1', 'id', 'tfc']
tfid.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>i1</th>
#       <th>id</th>
#       <th>tfc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>143</td>
#       <td>0.079950</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>145</td>
#       <td>0.081238</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>187</td>
#       <td>0.090773</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>224</td>
#       <td>0.158722</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>264</td>
#       <td>0.081173</td>
#     </tr>
# ...

# %%
df.join(tfid.set_index('id'), on='id')
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ii</th>
#       <th>id</th>
#       <th>word</th>
#       <th>freq</th>
#       <th>len</th>
#       <th>i1</th>
#       <th>tfc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>52313</td>
#       <td>21</td>
#       <td>mcintyre</td>
#       <td>2.0</td>
#       <td>8.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>52314</td>
#       <td>60</td>
#       <td>bit/s</td>
#       <td>2.0</td>
#       <td>5.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>52316</td>
#       <td>182</td>
# ...
